# %% [markdown]
# Copyright (c) 2020 [Qadeer Ah Aziz](qadeerahh@gmail.com)
#
# https://github.com/kadeeraziz/pashtopos
#
# [MIT License](https://github.com/kadeeraziz/pashtopos/master/LICENSE.txt)

# %% [markdown]
# ## Python web Scrapter - https://bbc.com/pashto

# %% [markdown]
# Note that the optional watermark extension is a small IPython notebook plugin that developed by [Sebastian Raschka](https://sebastianraschka.com)(https://github.com/rasbt/watermark) for printing date and time stamps, version numbers, and hardware information. You can just skip the following line(s).

# %%
# %load_ext watermark
# %watermark -a "Qadeer Ah. Aziz" -v -m -u -d -p numpy,pandas,bs4,requests,nltk
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Author: Qadeer Ah. Aziz
#
# Last updated: 2020-12-03
#
# Python implementation: CPython
# Python version       : 3.8.4
# IPython version      : 7.16.1
#
# numpy   : 1.19.0
# pandas  : 1.0.5
# bs4     : 4.9.1
# requests: 2.24.0
# nltk    : 3.4.4
#
# Compiler    : GCC 7.5.0
# OS          : Linux
# Release     : 4.19.76-linuxkit
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit

# %% [markdown]
# *The use of `watermark` is optional. You can install this Jupyter extension via*
#
#     conda install watermark -c conda-forge
#
# or
#
#     pip install watermark
#
# *For more information, please see: https://github.com/rasbt/watermark.*

# %% [markdown]
# ### Overview

# %% [markdown]
# - [Loading required packages](#Loading-required-packages)

# %% [markdown]
# # Loading required packages

# %%
from bs4 import BeautifulSoup
import requests
import nltk
import pandas as pd

# %%
response = requests.get('https://www.bbc.com/pashto/topics/cr50y57xj52t/page/5')
src = response.content
soup = BeautifulSoup(src, 'lxml')

# %%
hrefs = []

# %% [markdown]
# ### Getting the links to the other pages
# Since BBC Pashto changes their page struture regulary, at the time of writing this notebook, the links to other pages that has pashto text has/had a class 'qa-heading-link' name.

# %%
for a in soup.find_all('a', class_='qa-heading-link'):
    hrefs.append(a.attrs['href'])

# %%
hrefs
# Out:
# ['/pashto/afghanistan-53203195',
#  '/pashto/afghanistan-53202333',
#  '/pashto/afghanistan-53188879',
#  '/pashto/world-53184724',
#  '/pashto/afghanistan-53184728',
#  '/pashto/afghanistan-53174538',
#  '/pashto/53169024',
#  '/pashto/afghanistan-53161636',
#  '/pashto/afghanistan-53159426',
#  '/pashto/afghanistan-53146443']

# %%
# Getting only those urls that has same page structure. 
import re
new_hrefs = [href for href in hrefs if re.search('afghanistan', href)]

# %%
new_hrefs
# Out:
# ['/pashto/afghanistan-53203195',
#  '/pashto/afghanistan-53202333',
#  '/pashto/afghanistan-53188879',
#  '/pashto/afghanistan-53184728',
#  '/pashto/afghanistan-53174538',
#  '/pashto/afghanistan-53161636',
#  '/pashto/afghanistan-53159426',
#  '/pashto/afghanistan-53146443']

# %%
urls = [ 'https://www.bbc.com' + href for href in new_hrefs]

# %%
urls
# Out:
# ['https://www.bbc.com/pashto/afghanistan-53203195',
#  'https://www.bbc.com/pashto/afghanistan-53202333',
#  'https://www.bbc.com/pashto/afghanistan-53188879',
#  'https://www.bbc.com/pashto/afghanistan-53184728',
#  'https://www.bbc.com/pashto/afghanistan-53174538',
#  'https://www.bbc.com/pashto/afghanistan-53161636',
#  'https://www.bbc.com/pashto/afghanistan-53159426',
#  'https://www.bbc.com/pashto/afghanistan-53146443']

# %%
txtt = ''
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
ره د طالبانو له تړون وروسته، د طالبانو پرلپسې د نه منلو لوړې کچې تاوتریخوالي او ترهګریز بریدونه د اروپايي ټولنې د تمو خلاف دي. د امریکا دغه ګام سره به افغانستان کې د دغه هېواد د سرتېرو شمېر له ۸۶۰۰ نه ۴۵۰۰ ته ټیټ شي او دا له ۲۰۰۱ کال د افغان جګړې له پیلېدو راهیسې په دې جګړه کې د امریکايي سرتېرو تر ټولو کم شمېر دی.دې سره به له افغانستان د امریکا وتلو ته لار برابره شي چې ولسمشر ټرمپ پرې لا هم ټینګار کوي. سي اېن اېن وايي، که څه هم لا دا پرېکړه شوې نه ده، خو د امریکا دفاع وزیر مارک اسپر پرې تېره اونۍ خپل پلان له ناټو ملګرو سره هم په برسلز کې او د جمعې په ورځ خبرې کړې دي.د تېرې فبرورۍ پر ۲۹ د قطر دوحه کې د امریکا او طالبانو د سولې تړون له مخې امریکا ژمنه کړې چې که طالبان تړون ته ژمن پاتې شي تر راتلونکي اپرېل یا ۱۴ میاشتو پورې پورې خپل ځواکونه له افغانستان باسي.طالبانو هم ژمنه کړې چې وسلوالو ډلو ته به اجازه ور نه کړي چې افغانستان د امریکا او د هغې د ملاتړو پر ضد وکاروي، هم یې امریکا ګواښونکو ډلو سره د شلون او د افغانانو خپلمنځي خبرو پیلولو ژمنه کړې ده.د تړون له مخې امریکا باید راتلونکې میاشت یا جولای لومړیو پورې افغانستان کې د خپلو ځواکونو شمېر له ۱۳ زرو نه ۸۶۰۰ ته ټیټ کړي، خو د دوو امریکايي چارواکو په خبره، دوی له نېټې پوره کېدو مخکې د ځواکونو شمېر اتو زرو شپږ سوو ته ټیټ کړی دی.له افغانستان د امریکايي ځواکونو وتل پیل شولله افغانستان د ټولو امريکايي ځواکونو وتل د طالبانو "ځانګړو ګامونو" پورې تړلي"ټرمپ افغانستان کې د امریکايي ځواکونو ماموریت بشپړول غواړي"د امریکا د بهرنیو چارو وزارت او پنټګان یا دفاع وزارت کې چارواکو بیا بیا ویلي چې تر ۸۶۰۰ د سرتېرو نور کمول به شرایطو پورې تړلي وي.د څلور زرو نورو سرتېرو کمولو پرېکړه په داسې مهال ده چې لا هم د افغانانو خپلمنځي خبرې نه دي پیل شوې. د دې خبرو پیلولو لپاره د طالبانو مهم شرط پنځه زره طالب بندیان خوشي کول دي او مقابل کې حکومت له طالبانو د تاوتریخوالي کمول غواړي ...

# %% [markdown]
# ### tokenizing the collected texts

# %%
tokens = nltk.tokenize.WordPunctTokenizer().tokenize(txtt)

# %%
len(tokens)
# Out:
# 4333

# %%
df = pd.DataFrame(tokens)

# %%
df.columns = ['word']

# %%
df
# Out:
#        word
# 0         ۷
# 1     چنګاښ
# 2      ۱۳۹۹
# 3         -
# 4        ۲۷
# ...     ...
# 4328    تېر
# 4329   حالت
# 4330     ته
# 4331  وګرځي
# 4332      .
#
# [4333 rows x 1 columns]

# %%
df.dropna()
# Out:
#        word
# 0         ۷
# 1     چنګاښ
# 2      ۱۳۹۹
# 3         -
# 4        ۲۷
# ...     ...
# 4328    تېر
# 4329   حالت
# 4330     ته
# 4331  وګرځي
# 4332      .
#
# [4333 rows x 1 columns]

# %%
df.to_excel('./untagged/bbc4.xlsx', index=False)

# %%
df.count()
# Out:
# word    4333
# dtype: int64
